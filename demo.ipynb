# %% [markdown]
# # RWT Qlax Bootcamp — Python Demo
# **RedWaves Tech** | Applied Data Analytics Bootcamp
#
# Run each cell with **Shift+Enter** to see the output.

# %% [markdown]
# ## 1. Load the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("rwt_qlax_health_survey.csv")
print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
df.head(10)

# %% [markdown]
# ## 2. Descriptive Statistics

# %%
df.describe()

# %% [markdown]
# ## 3. Frequency Counts

# %%
print("SCREENING RESULTS")
print(df['screening_result'].value_counts())
print("\nFACILITIES BY REGION")
print(df['region'].value_counts())

# %% [markdown]
# ## 4. Data Quality Check
# Can you spot the 5 intentional issues?

# %%
print("Missing values per column:")
print(df.isnull().sum())
print(f"\nDuplicate IDs: {df['patient_id'].duplicated().sum()}")
print(f"Unique sex values: {df['sex'].unique()}")
print(f"\nMin hb_level: {df['hb_level'].min()}")
print(f"Max bmi: {df['bmi'].max()}")

# %% [markdown]
# ## 5. Visualizations

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Age distribution
axes[0].hist(df['age'], bins=20, color='#e94560', edgecolor='#1a1a2e')
axes[0].set_title('Age Distribution')
axes[0].set_xlabel('Age')

# BMI distribution
axes[1].hist(df['bmi'], bins=20, color='#0f3460', edgecolor='#1a1a2e')
axes[1].set_title('BMI Distribution')
axes[1].set_xlabel('BMI')

# Screening results
results = df['screening_result'].value_counts()
axes[2].bar(results.index, results.values, color=['#2ecc71', '#e94560', '#f39c12'])
axes[2].set_title('Screening Results')

plt.suptitle('RWT Qlax Bootcamp — Health Survey Analysis', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Simple Regression
# Does age or BMI predict hemoglobin level?

# %%
import statsmodels.api as sm

X = df[['age', 'bmi']].dropna()
y = df.loc[X.index, 'hb_level']
X = sm.add_constant(X)

model = sm.OLS(y, X).fit()
print(model.summary())

# %% [markdown]
# ---
# **RedWaves Tech** — Engineering Intelligence Systems for the Future
#
# Ready for more? Ask about the 4-Week Data Analytics Certification Program.
